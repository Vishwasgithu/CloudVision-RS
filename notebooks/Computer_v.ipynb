# %%
import cv2

print(cv2.__version__)
# Out:
# 4.13.0

# %%
import numpy as np
import torch

image = np.random.randint(

    0,
    256,
    (256,256,3)

)

tensor = torch.tensor(image)

print(type(image))
print(type(tensor))

print(image.shape)
print(tensor.shape)
# Out:
# <class 'numpy.ndarray'>
# <class 'torch.Tensor'>
# (256, 256, 3)
# torch.Size([256, 256, 3])

# %%
import cv2
import numpy as np
import torch

image = np.random.randint(
    0,
    256,
    (256,256,3)
)

tensor = torch.tensor(image)
